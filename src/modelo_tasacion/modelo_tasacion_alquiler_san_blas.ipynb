# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
import pylab as plt
import seaborn as sns
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor as RFR  
from sklearn.tree import ExtraTreeRegressor as ETR
from xgboost import XGBRegressor as XGBR
from sklearn.metrics import mean_squared_error as mse

# %%
mad_total = pd.read_csv('../analisis_exploratorio/mad_total_limp.csv')
mad_centro = pd.read_csv('../analisis_exploratorio/mad_int_limp.csv')
mad_exterior = pd.read_csv('../analisis_exploratorio/mad_ext_limp.csv')
alquiler = pd.read_csv('../analisis_exploratorio/alquiler_limp.csv')

# %%
alquiler
# Out:
#       descripcion     zona    Distrito  precio  superficie  habitaciones  \
# 0               4  central  Arganzuela   600.0          25             0
# 1               0  central  Arganzuela   700.0          35             2
# 2               0  central  Arganzuela   790.0          40             1
# 3               4  central  Arganzuela   800.0          40             0
# 4               0  central  Arganzuela   800.0          35             1
# ...           ...      ...         ...     ...         ...           ...
# 8177            0  central  Villaverde  1465.0          45             1
# 8178            3  central  Villaverde  1475.0          64             2
# 8179            0  central  Villaverde  1500.0          90             4
# 8180            0  central  Villaverde  1895.0          80             2
# 8181            0  central  Villaverde  2300.0          65             2
#
#       plantas  caract  ascensor  garaje       €/m2  distrito_€/m2  \
# 0           3       3         3       0  24.000000      21.037674
# 1           0       1         0       0  20.000000      21.037674
# 2           1       0         1       0  19.750000      21.037674
# 3           3       3         3       0  20.000000      21.037674
# 4           4       0         1       0  22.857143      21.037674
# ...       ...     ...       ...     ...        ...            ...
# 8177        6       1         1       0  32.555556      15.340223
# 8178        5       1         1       0  23.046875      15.340223
# 8179        6       1         1       0  16.666667      15.340223
# 8180        0       1         1       0  23.687500      15.340223
# 8181        1       3         0       0  35.384615      15.340223
#
#         media_alq    pais  ciudad
# 0     1530.949664  españa  madrid
# 1     1530.949664  españa  madrid
# 2     1530.949664  españa  madrid
# 3     1530.949664  españa  madrid
# 4     1530.949664  españa  madrid
# ...           ...     ...     ...
# 8177  1022.743902  españa  madrid
# 8178  1022.743902  españa  madrid
# 8179  1022.743902  españa  madrid
# 8180  1022.743902  españa  madrid
# 8181  1022.743902  españa  madrid
#
# [8182 rows x 15 columns]

# %%
alquiler.Distrito.value_counts()
# Out:
# Distrito
# Centro                   1263
# Salamanca                 957
# noroeste                  693
# norte                     658
# Chamberi                  582
# Chamartin                 516
# Tetuan                    507
# Retiro                    299
# Arganzuela                298
# Moncloa - Aravaca         264
# sur                       258
# Hortaleza                 245
# Fuencarral - El Pardo     242
# Ciudad Lineal             207
# corredor de henares       182
# San Blas - Canillejas     143
# Latina                    137
# Carabanchel               122
# Puente de Vallecas        105
# sureste                    91
# Villaverde                 82
# Usera                      70
# Vicalvaro                  70
# Villa de Vallecas          67
# suroeste                   66
# Barajas                    30
# Moratalaz                  28
# Name: count, dtype: int64

# %%
#df1 = alquiler
df1 = alquiler[alquiler['Distrito']=='San Blas - Canillejas']

# %%
sns.boxplot(x=df1['precio'])
plt.show()

# %%
df1 = df1.drop(columns=['distrito_€/m2','€/m2','zona','Distrito','media_alq','garaje','pais','ciudad'])
#df1 = df1.drop(columns=['distrito_€/m2','€/m2','media_alq'])
#df1 = df1.drop(columns=['distrito_€/m2','€/m2','media_alq','garaje','ascensor','caract'])

# %%
X = df1.drop('precio', axis=1)

y = df1.precio

# %%
X_train, X_test, y_train, y_test = tts(X, y,
                                      train_size=0.8,
                                      test_size=0.2,
                                      random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((114, 6), (29, 6), (114,), (29,))

# %%
"""X = pd.get_dummies(X, columns=['distrito'], dtype=int, drop_first=True)

X_train = pd.get_dummies(X_train, columns=['distrito'], dtype=int, drop_first=True)

X_test = pd.get_dummies(X_test, columns=['distrito'], dtype=int, drop_first=True)"""
# Out:
# "X = pd.get_dummies(X, columns=['distrito'], dtype=int, drop_first=True)\n\nX_train = pd.get_dummies(X_train, columns=['distrito'], dtype=int, drop_first=True)\n\nX_test = pd.get_dummies(X_test, columns=['distrito'], dtype=int, drop_first=True)"

# %%
"""X = pd.get_dummies(X, columns=['zona'], dtype=int, drop_first=True)

X_train = pd.get_dummies(X_train, columns=['zona'], dtype=int, drop_first=True)

X_test = pd.get_dummies(X_test, columns=['zona'], dtype=int, drop_first=True)"""
# Out:
# "X = pd.get_dummies(X, columns=['zona'], dtype=int, drop_first=True)\n\nX_train = pd.get_dummies(X_train, columns=['zona'], dtype=int, drop_first=True)\n\nX_test = pd.get_dummies(X_test, columns=['zona'], dtype=int, drop_first=True)"

# %%
rfr = RFR(n_estimators=500, random_state=20)

rfr.fit(X_train, y_train)

y_pred = rfr.predict(X_test)

mse(y_test, y_pred, squared=False)
# Out:
# 222.55021174940362

# %%
print(f"Test accuracy: {rfr.score(X_test, y_test):0.4f}")
# Out:
# Test accuracy: 0.1147

# %%
df1.precio.mean()
# Out:
# 1209.013986013986

# %%
mse(y_test, y_pred, squared=False)*100/df1.precio.mean()
# Out:
# 18.4075795916251

# %%
dict(zip(X.columns, rfr.feature_importances_*100))
# Out:
# {'descripcion': 1.6574833614480422,
#  'superficie': 64.41399003004172,
#  'habitaciones': 21.961103676464695,
#  'plantas': 5.844771477453063,
#  'caract': 2.8672356965508947,
#  'ascensor': 3.2554157580416105}

# %%
xgbr=XGBR(random_state=42)

xgbr.fit(X_train, y_train)

y_pred = xgbr.predict(X_test)

mse(y_test, y_pred, squared=False)
# Out:
# 167.44029349348207

# %%
print(f"Test accuracy: {xgbr.score(X_test, y_test):0.4f}")
# Out:
# Test accuracy: 0.4988

# %%
df1.precio.mean()
# Out:
# 1209.013986013986

# %%
mse(y_test, y_pred, squared=False)*100/df1.precio.mean()
# Out:
# 13.849326428846217

# %%
dict(zip(X.columns, xgbr.feature_importances_*100))
# Out:
# {'descripcion': 1.0254858,
#  'superficie': 3.8072898,
#  'habitaciones': 73.16855,
#  'plantas': 1.0593134,
#  'caract': 8.214043,
#  'ascensor': 12.725324}

# %%
X1 = df1.drop(columns='precio')
y1 = df1.precio

# %%
xgbr=XGBR(random_state=42)
xgbr.fit(X1, y1)
y1_pred = xgbr.predict(X1)
mse(y1_pred, y1, squared=False)
# Out:
# 33.629119826196586

# %%
dict(zip(X.columns, xgbr.feature_importances_*100))
# Out:
# {'descripcion': 2.249419,
#  'superficie': 4.2985654,
#  'habitaciones': 69.16478,
#  'plantas': 1.4640112,
#  'caract': 11.500683,
#  'ascensor': 11.322542}

# %%
df1.precio.mean()
# Out:
# 1209.013986013986

# %%
print(f"Test accuracy: {xgbr.score(X1, y1):0.4f}")
# Out:
# Test accuracy: 0.9945

# %%
mse(y1_pred, y1, squared=False)*100/df1.precio.mean()
# Out:
# 2.7815327378526753

# %%
y1_pred = pd.DataFrame(y1_pred, columns=['prediccion'])
y1 = pd.DataFrame(y1)

# %%
y1 = y1.reset_index(drop=True)
y1_pred = y1_pred.reset_index(drop=True)

# %%
con = pd.concat([y1,y1_pred], axis=1)

# %%
con['dif'] = abs(con['precio'] - con['prediccion'])

con['porcen'] = con['dif']*100/ con['precio']

# %%
con
# Out:
#      precio   prediccion         dif     porcen
# 0     560.0   560.898315    0.898315   0.160413
# 1     605.0   604.908386    0.091614   0.015143
# 2     695.0   694.040588    0.959412   0.138045
# 3     750.0   747.416382    2.583618   0.344482
# 4     790.0   789.293213    0.706787   0.089467
# 5     795.0   860.155151   65.155151   8.195617
# 6     795.0   799.057007    4.057007   0.510315
# 7     800.0   807.870422    7.870422   0.983803
# 8     800.0   860.155151   60.155151   7.519394
# 9     800.0   860.155151   60.155151   7.519394
# 10    800.0   799.057007    0.942993   0.117874
# 11    830.0   837.381958    7.381958   0.889393
# 12    850.0   974.057983  124.057983  14.595057
# 13    850.0   860.155151   10.155151   1.194724
# 14    850.0   860.155151   10.155151   1.194724
# 15    850.0   849.286560    0.713440   0.083934
# 16    850.0   851.263367    1.263367   0.148631
# 17    850.0   853.058777    3.058777   0.359856
# 18    875.0   876.497070    1.497070   0.171094
# 19    875.0   875.988098    0.988098   0.112926
# 20    880.0   882.234558    2.234558   0.253927
# 21    890.0   894.880676    4.880676   0.548391
# 22    895.0   896.737793    1.737793   0.194167
# 23    895.0   898.991028    3.991028   0.445925
# 24    900.0   899.892578    0.107422   0.011936
# 25    900.0   905.094788    5.094788   0.566088
# 26    900.0   896.694885    3.305115   0.367235
# 27    900.0   899.656799    0.343201   0.038133
# 28    900.0   899.891663    0.108337   0.012037
# 29    915.0   920.630615    5.630615   0.615368
# 30    930.0   930.090027    0.090027   0.009680
# 31    950.0   958.534302    8.534302   0.898348
# 32    950.0   954.150208    4.150208   0.436864
# 33    950.0   951.210388    1.210388   0.127409
# 34    950.0   860.155151   89.844849   9.457352
# 35    970.0   970.435242    0.435242   0.044870
# 36    975.0   860.155151  114.844849  11.778959
# 37    975.0   971.215820    3.784180   0.388121
# 38    980.0   978.189636    1.810364   0.184731
# 39    980.0   982.211731    2.211731   0.225687
# 40    990.0   993.186157    3.186157   0.321834
# 41    990.0   987.141968    2.858032   0.288690
# 42    999.0   997.359863    1.640137   0.164178
# 43   1000.0  1002.577393    2.577393   0.257739
# 44   1000.0   998.825684    1.174316   0.117432
# 45   1000.0  1002.372559    2.372559   0.237256
# 46   1000.0  1000.672546    0.672546   0.067255
# 47   1000.0  1151.529297  151.529297  15.152930
# 48   1000.0   999.947937    0.052063   0.005206
# 49   1020.0  1020.895386    0.895386   0.087783
# 50   1050.0  1049.912231    0.087769   0.008359
# 51   1050.0  1051.010620    1.010620   0.096250
# 52   1070.0  1073.144043    3.144043   0.293836
# 53   1090.0  1090.115723    0.115723   0.010617
# 54   1090.0  1090.115723    0.115723   0.010617
# 55   1090.0  1090.115723    0.115723   0.010617
# 56   1090.0  1090.115723    0.115723   0.010617
# 57   1090.0  1090.115723    0.115723   0.010617
# 58   1090.0  1090.115723    0.115723   0.010617
# 59   1090.0  1090.115723    0.115723   0.010617
# 60   1090.0  1090.115723    0.115723   0.010617
# 61   1090.0  1090.115723    0.115723   0.010617
# 62   1100.0  1100.264160    0.264160   0.024015
# 63   1100.0  1099.388428    0.611572   0.055597
# 64   1100.0  1095.964844    4.035156   0.366832
# 65   1100.0  1096.436279    3.563721   0.323975
# 66   1100.0  1099.388428    0.611572   0.055597
# 67   1100.0  1098.778564    1.221436   0.111040
# 68   1100.0   974.057983  125.942017  11.449274
# 69   1100.0  1101.754272    1.754272   0.159479
# 70   1100.0  1099.521973    0.478027   0.043457
# 71   1100.0  1095.486572    4.513428   0.410312
# 72   1100.0  1100.439819    0.439819   0.039984
# 73   1100.0  1095.304199    4.695801   0.426891
# 74   1110.0  1097.336182   12.663818   1.140885
# 75   1125.0  1125.815552    0.815552   0.072493
# 76   1150.0  1161.675049   11.675049   1.015222
# 77   1150.0  1187.595337   37.595337   3.269160
# 78   1150.0  1150.698486    0.698486   0.060738
# 79   1175.0  1174.374512    0.625488   0.053233
# 80   1180.0  1179.774048    0.225952   0.019148
# 81   1200.0  1200.653564    0.653564   0.054464
# 82   1200.0  1199.483887    0.516113   0.043009
# 83   1200.0  1196.994629    3.005371   0.250448
# 84   1200.0  1200.435913    0.435913   0.036326
# 85   1200.0  1200.364990    0.364990   0.030416
# 86   1200.0  1198.635498    1.364502   0.113708
# 87   1200.0  1196.994629    3.005371   0.250448
# 88   1200.0  1204.294312    4.294312   0.357859
# 89   1200.0  1200.284546    0.284546   0.023712
# 90   1200.0  1204.964966    4.964966   0.413747
# 91   1200.0  1198.489014    1.510986   0.125916
# 92   1200.0  1193.858887    6.141113   0.511759
# 93   1200.0  1199.378906    0.621094   0.051758
# 94   1200.0  1199.856567    0.143433   0.011953
# 95   1200.0  1202.872070    2.872070   0.239339
# 96   1200.0  1244.784180   44.784180   3.732015
# 97   1200.0  1203.766968    3.766968   0.313914
# 98   1200.0  1197.300537    2.699463   0.224955
# 99   1220.0  1187.595337   32.404663   2.656120
# 100  1250.0  1259.604492    9.604492   0.768359
# 101  1250.0  1272.651123   22.651123   1.812090
# 102  1250.0  1372.585693  122.585693   9.806855
# 103  1250.0  1249.392944    0.607056   0.048564
# 104  1265.0  1259.575317    5.424683   0.428829
# 105  1300.0  1300.588501    0.588501   0.045269
# 106  1300.0  1298.909424    1.090576   0.083890
# 107  1300.0  1301.983643    1.983643   0.152588
# 108  1300.0  1272.651123   27.348877   2.103760
# 109  1300.0  1151.529297  148.470703  11.420823
# 110  1300.0  1372.659912   72.659912   5.589224
# 111  1300.0  1244.784180   55.215820   4.247371
# 112  1300.0  1303.020996    3.020996   0.232384
# 113  1300.0  1298.955322    1.044678   0.080360
# 114  1300.0  1297.524170    2.475830   0.190448
# 115  1350.0  1347.147339    2.852661   0.211308
# 116  1395.0  1392.220947    2.779053   0.199215
# 117  1395.0  1394.708130    0.291870   0.020923
# 118  1400.0  1400.063477    0.063477   0.004534
# 119  1400.0  1399.256592    0.743408   0.053101
# 120  1400.0  1400.063477    0.063477   0.004534
# 121  1400.0  1400.040527    0.040527   0.002895
# 122  1400.0  1391.445679    8.554321   0.611023
# 123  1450.0  1372.659912   77.340088   5.333799
# 124  1500.0  1499.047607    0.952393   0.063493
# 125  1500.0  1499.644165    0.355835   0.023722
# 126  1500.0  1500.719849    0.719849   0.047990
# 127  1500.0  1372.585693  127.414307   8.494287
# 128  1570.0  1567.121704    2.878296   0.183331
# 129  1590.0  1592.295532    2.295532   0.144373
# 130  1620.0  1618.350464    1.649536   0.101823
# 131  1650.0  1650.921387    0.921387   0.055842
# 132  1700.0  1700.417358    0.417358   0.024550
# 133  1800.0  1797.299927    2.700073   0.150004
# 134  1850.0  1849.390991    0.609009   0.032919
# 135  1950.0  1950.299683    0.299683   0.015368
# 136  1950.0  1949.846680    0.153320   0.007863
# 137  2310.0  2308.491699    1.508301   0.065294
# 138  2750.0  2749.883789    0.116211   0.004226
# 139  2900.0  2900.968750    0.968750   0.033405
# 140  3000.0  2999.327148    0.672852   0.022428
# 141  3400.0  3399.391602    0.608398   0.017894
# 142  3500.0  3497.973145    2.026855   0.057910

# %%
con.to_excel('san_blas_tasacion_alquiler.xlsx', index=False)
