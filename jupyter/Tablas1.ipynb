# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../../Posibles tablas/death-rate-by-cause-who-mdb.csv')

df
# Out:
#          Entity Code  Year  \
# 0       Albania  ALB  1987
# 1       Albania  ALB  1988
# 2       Albania  ALB  1989
# 3       Albania  ALB  1992
# 4       Albania  ALB  1993
# ...         ...  ...   ...
# 4702  Venezuela  VEN  2012
# 4703  Venezuela  VEN  2013
# 4704  Venezuela  VEN  2014
# 4705  Venezuela  VEN  2016
# 4706  Venezuela  VEN  2015
#
#       Age-standardized deaths that are from malignant neoplasms per 100,000 people, in both sexes aged all ages  \
# 0                                             88.860980
# 1                                             99.332530
# 2                                             92.817200
# 3                                             74.528990
# 4                                             66.275505
# ...                                                 ...
# 4702                                          98.584920
# 4703                                          96.557110
# 4704                                          98.284260
# ...

# %%
df2 = pd.read_csv('../../Posibles tablas/intervalos_edad_españa.csv', encoding='latin-1')
df2
# Out:
#      Edad (grupos quinquenales);Españoles/Extranjeros;Sexo;Año;Total
# 0        TOTAL EDADES;TOTAL;Ambos sexos;2022;47.475.420
# 1        TOTAL EDADES;TOTAL;Ambos sexos;2021;47.385.107
# 2        TOTAL EDADES;TOTAL;Ambos sexos;2020;47.450.795
# 3        TOTAL EDADES;TOTAL;Ambos sexos;2019;47.026.208
# 4        TOTAL EDADES;TOTAL;Ambos sexos;2018;46.722.980
# ...                                                 ...
# 4945        100 años y más;Extranjeros;Mujeres;2002;199
# 4946        100 años y más;Extranjeros;Mujeres;2001;276
# 4947        100 años y más;Extranjeros;Mujeres;2000;239
# 4948        100 años y más;Extranjeros;Mujeres;1999;189
# 4949         100 años y más;Extranjeros;Mujeres;1998;46
#
# [4950 rows x 1 columns]

# %%
df_3 = pd.read_csv('../../Posibles tablas/cause_of_deaths.csv')

df_3
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...

# %%
df2_split = df2["Edad (grupos quinquenales);Españoles/Extranjeros;Sexo;Año;Total"].str.split(";", expand=True)

# Asignar nombres de columnas a las nuevas columnas
nombres_columnas = ['age', 'spanish/foreign', 'sex', 'year', 'total']
df2_split.columns = nombres_columnas

# Reemplazar los nombres de las columnas antiguas con los nombres de las columnas correctos
df2 = pd.concat([df2, df2_split], axis=1)
df2.drop(columns=["Edad (grupos quinquenales);Españoles/Extranjeros;Sexo;Año;Total"], inplace=True)

df2
# Out:
#                  age spanish/foreign          sex  year       total
# 0       TOTAL EDADES           TOTAL  Ambos sexos  2022  47.475.420
# 1       TOTAL EDADES           TOTAL  Ambos sexos  2021  47.385.107
# 2       TOTAL EDADES           TOTAL  Ambos sexos  2020  47.450.795
# 3       TOTAL EDADES           TOTAL  Ambos sexos  2019  47.026.208
# 4       TOTAL EDADES           TOTAL  Ambos sexos  2018  46.722.980
# ...              ...             ...          ...   ...         ...
# 4945  100 años y más     Extranjeros      Mujeres  2002         199
# 4946  100 años y más     Extranjeros      Mujeres  2001         276
# 4947  100 años y más     Extranjeros      Mujeres  2000         239
# 4948  100 años y más     Extranjeros      Mujeres  1999         189
# 4949  100 años y más     Extranjeros      Mujeres  1998          46
#
# [4950 rows x 5 columns]

# %%
df2.shape
# Out:
# (4950, 5)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4950 entries, 0 to 4949
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              4950 non-null   object
#  1   spanish/foreign  4950 non-null   object
#  2   sex              4950 non-null   object
#  3   year             4950 non-null   object
#  4   total            4950 non-null   object
# dtypes: object(5)
# memory usage: 193.5+ KB

# %%
df2['total'] = df2['total'].str.replace('.', '')
df2['year'] = df2['year'].astype(int)
df2['total'] = df2['total'].astype(int)

# %%
df_2021 = df[df['Year']==2021]
df_2021.shape
# Out:
# (23, 12)

# %%
df_2020 = df[df['Year']==2020]
df_2020.shape
# Out:
# (57, 12)

# %%
df_2019 = df[df['Year']==2019]
df_2019.shape
# Out:
# (77, 12)

# %%
df_spain = df[(df['Entity']== 'Spain') & (df['Year']==2019)]
df_spain
# Out:
#      Entity Code  Year  \
# 3963  Spain  ESP  2019
#
#       Age-standardized deaths that are from malignant neoplasms per 100,000 people, in both sexes aged all ages  \
# 3963                                          101.35696
#
#       Age-standardized deaths that are from cardiovascular diseases per 100,000 people, in both sexes aged all ages  \
# 3963                                           77.61572
#
#       Age-standardized deaths that are from respiratory infections per 100,000 people, in both sexes aged all ages  \
# 3963                                           7.637719
#
#       Age-standardized deaths that are from infectious and parasitic diseases per 100,000 people, in both sexes aged all ages  \
# 3963                                           5.071931
#
#       Age-standardized deaths that are from digestive diseases per 100,000 people, in both sexes aged all ages  \
# 3963                                          16.907635
#
# ...

# %%
df_3_spain_2019 = df_3[(df_3['Country/Territory']=='Spain') & (df_3['Year']==2019)]

df_3_spain_2019
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 5129             Spain  ESP  2019         155
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 5129                                    29208                 6137
#
#       Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  \
# 5129                       467        0       425                     335
#
#       Maternal Disorders  HIV/AIDS  Drug Use Disorders  Tuberculosis  \
# 5129                  15       679                 728           378
#
#       Cardiovascular Diseases  Lower Respiratory Infections  \
# 5129                   131493                         14184
#
#       Neonatal Disorders  Alcohol Use Disorders  Self-harm  \
# 5129                 483                    429       3759
#
#       Exposure to Forces of Nature  Diarrheal Diseases  \
# 5129                             0                1213
#
# ...

# %%
df2_2019 = df2[df2['year']==2019]
df2_2019.head(60)
# Out:
#                age spanish/foreign          sex  year     total
# 3     TOTAL EDADES           TOTAL  Ambos sexos  2019  47026208
# 28    TOTAL EDADES           TOTAL      Hombres  2019  23042428
# 53    TOTAL EDADES           TOTAL      Mujeres  2019  23983780
# 78    TOTAL EDADES       Españoles  Ambos sexos  2019  41989330
# 103   TOTAL EDADES       Españoles      Hombres  2019  20522283
# 128   TOTAL EDADES       Españoles      Mujeres  2019  21467047
# 153   TOTAL EDADES     Extranjeros  Ambos sexos  2019   5036878
# 178   TOTAL EDADES     Extranjeros      Hombres  2019   2520145
# 203   TOTAL EDADES     Extranjeros      Mujeres  2019   2516733
# 228       0-4 años           TOTAL  Ambos sexos  2019   2038663
# 253       0-4 años           TOTAL      Hombres  2019   1048153
# 278       0-4 años           TOTAL      Mujeres  2019    990510
# 303       0-4 años       Españoles  Ambos sexos  2019   1766625
# 328       0-4 años       Españoles      Hombres  2019    908191
# ...

# %%
df2_2019 = df2_2019[(df2_2019['spanish/foreign']== 'TOTAL') & (df2_2019['sex']=='Ambos sexos')]
df2_2019
# Out:
#                  age spanish/foreign          sex  year     total
# 3       TOTAL EDADES           TOTAL  Ambos sexos  2019  47026208
# 228         0-4 años           TOTAL  Ambos sexos  2019   2038663
# 453         5-9 años           TOTAL  Ambos sexos  2019   2355494
# 678       10-14 años           TOTAL  Ambos sexos  2019   2491371
# 903       15-19 años           TOTAL  Ambos sexos  2019   2322446
# 1128      20-24 años           TOTAL  Ambos sexos  2019   2305303
# 1353      25-29 años           TOTAL  Ambos sexos  2019   2566361
# 1578      30-34 años           TOTAL  Ambos sexos  2019   2860390
# 1803      35-39 años           TOTAL  Ambos sexos  2019   3492600
# 2028      40-44 años           TOTAL  Ambos sexos  2019   4013566
# 2253      45-49 años           TOTAL  Ambos sexos  2019   3818921
# 2478      50-54 años           TOTAL  Ambos sexos  2019   3637840
# 2703      55-59 años           TOTAL  Ambos sexos  2019   3266949
# ...

# %%
cadena_valores = "0-4 8.86 5-9 8.69 10-14 8.60 15-19 8.47 20-24 8.22 25-29 7.93 30-34 7.61 35-39 7.15 40-44 6.59 45-49 6.04 50-54 5.37 55-59 4.55 60-64 3.72 65-69 2.96 70-74 2.21 75-79 1.52 80-84 0.91 85-89 0.44 90-94 0.15 95-99 0.04"

# Divide la cadena de valores en una lista
valores = cadena_valores.split()

# Crea un diccionario
diccionario = {}

# Itera sobre los valores y agrégalos al diccionario
for i in range(0, len(valores), 2):
    diccionario[valores[i]] = float(valores[i+1])
    
diccionario
# Out:
# {'0-4': 8.86,
#  '5-9': 8.69,
#  '10-14': 8.6,
#  '15-19': 8.47,
#  '20-24': 8.22,
#  '25-29': 7.93,
#  '30-34': 7.61,
#  '35-39': 7.15,
#  '40-44': 6.59,
#  '45-49': 6.04,
#  '50-54': 5.37,
#  '55-59': 4.55,
#  '60-64': 3.72,
#  '65-69': 2.96,
#  '70-74': 2.21,
#  '75-79': 1.52,
#  '80-84': 0.91,
#  '85-89': 0.44,
#  '90-94': 0.15,
#  '95-99': 0.04}

# %%
diccionario = {
 'TOTAL EDADES': 1,
 '0-4': 8.86,
 '5-9': 8.69,
 '10-14': 8.6,
 '15-19': 8.47,
 '20-24': 8.22,
 '25-29': 7.93,
 '30-34': 7.61,
 '35-39': 7.15,
 '40-44': 6.59,
 '45-49': 6.04,
 '50-54': 5.37,
 '55-59': 4.55,
 '60-64': 3.72,
 '65-69': 2.96,
 '70-74': 2.21,
 '75-79': 1.52,
 '80-84': 0.91,
 '85-89': 0.44,
 '90-94': 0.15,
 '95-99': 0.04,
 '100 y más': 1}

# %%
df_tasa = pd.DataFrame(list(diccionario.items()), columns=['age', 'tasa'])
df_tasa
# Out:
#              age  tasa
# 0   TOTAL EDADES  1.00
# 1            0-4  8.86
# 2            5-9  8.69
# 3          10-14  8.60
# 4          15-19  8.47
# 5          20-24  8.22
# 6          25-29  7.93
# 7          30-34  7.61
# 8          35-39  7.15
# 9          40-44  6.59
# 10         45-49  6.04
# 11         50-54  5.37
# 12         55-59  4.55
# 13         60-64  3.72
# 14         65-69  2.96
# 15         70-74  2.21
# 16         75-79  1.52
# 17         80-84  0.91
# 18         85-89  0.44
# 19         90-94  0.15
# 20         95-99  0.04
# 21     100 y más  1.00

# %%
df2_2019['age'] = df2_2019['age'].str.replace('años','')

df2_2019 = df2_2019.reset_index(drop=True)

df2_2019
# Out:
#              age spanish/foreign          sex  year     total
# 0   TOTAL EDADES           TOTAL  Ambos sexos  2019  47026208
# 1           0-4            TOTAL  Ambos sexos  2019   2038663
# 2           5-9            TOTAL  Ambos sexos  2019   2355494
# 3         10-14            TOTAL  Ambos sexos  2019   2491371
# 4         15-19            TOTAL  Ambos sexos  2019   2322446
# 5         20-24            TOTAL  Ambos sexos  2019   2305303
# 6         25-29            TOTAL  Ambos sexos  2019   2566361
# 7         30-34            TOTAL  Ambos sexos  2019   2860390
# 8         35-39            TOTAL  Ambos sexos  2019   3492600
# 9         40-44            TOTAL  Ambos sexos  2019   4013566
# 10        45-49            TOTAL  Ambos sexos  2019   3818921
# 11        50-54            TOTAL  Ambos sexos  2019   3637840
# 12        55-59            TOTAL  Ambos sexos  2019   3266949
# 13        60-64            TOTAL  Ambos sexos  2019   2799111
# ...

# %%
df2_2019_tasa  = pd.concat([df2_2019, df_tasa], axis=1)

df2_2019_tasa
# Out:
#              age spanish/foreign          sex  year     total           age  \
# 0   TOTAL EDADES           TOTAL  Ambos sexos  2019  47026208  TOTAL EDADES
# 1           0-4            TOTAL  Ambos sexos  2019   2038663           0-4
# 2           5-9            TOTAL  Ambos sexos  2019   2355494           5-9
# 3         10-14            TOTAL  Ambos sexos  2019   2491371         10-14
# 4         15-19            TOTAL  Ambos sexos  2019   2322446         15-19
# 5         20-24            TOTAL  Ambos sexos  2019   2305303         20-24
# 6         25-29            TOTAL  Ambos sexos  2019   2566361         25-29
# 7         30-34            TOTAL  Ambos sexos  2019   2860390         30-34
# 8         35-39            TOTAL  Ambos sexos  2019   3492600         35-39
# 9         40-44            TOTAL  Ambos sexos  2019   4013566         40-44
# 10        45-49            TOTAL  Ambos sexos  2019   3818921         45-49
# ...

# %%
df2_2019_tasa['product'] = df2_2019_tasa['total'] * df2_2019_tasa['tasa']

df2_2019_tasa
# Out:
#              age spanish/foreign          sex  year     total           age  \
# 0   TOTAL EDADES           TOTAL  Ambos sexos  2019  47026208  TOTAL EDADES
# 1           0-4            TOTAL  Ambos sexos  2019   2038663           0-4
# 2           5-9            TOTAL  Ambos sexos  2019   2355494           5-9
# 3         10-14            TOTAL  Ambos sexos  2019   2491371         10-14
# 4         15-19            TOTAL  Ambos sexos  2019   2322446         15-19
# 5         20-24            TOTAL  Ambos sexos  2019   2305303         20-24
# 6         25-29            TOTAL  Ambos sexos  2019   2566361         25-29
# 7         30-34            TOTAL  Ambos sexos  2019   2860390         30-34
# 8         35-39            TOTAL  Ambos sexos  2019   3492600         35-39
# 9         40-44            TOTAL  Ambos sexos  2019   4013566         40-44
# 10        45-49            TOTAL  Ambos sexos  2019   3818921         45-49
# ...
