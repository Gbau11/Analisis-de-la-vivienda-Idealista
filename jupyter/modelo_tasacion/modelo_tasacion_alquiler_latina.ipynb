# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
import pylab as plt
import seaborn as sns
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor as RFR  
from sklearn.tree import ExtraTreeRegressor as ETR
from xgboost import XGBRegressor as XGBR
from sklearn.metrics import mean_squared_error as mse

# %%
mad_total = pd.read_csv('../analisis_exploratorio/mad_total_limp.csv')
mad_centro = pd.read_csv('../analisis_exploratorio/mad_int_limp.csv')
mad_exterior = pd.read_csv('../analisis_exploratorio/mad_ext_limp.csv')
alquiler = pd.read_csv('../analisis_exploratorio/alquiler_limp.csv')

# %%
alquiler
# Out:
#       descripcion     zona    Distrito  precio  superficie  habitaciones  \
# 0               4  central  Arganzuela   600.0          25             0
# 1               0  central  Arganzuela   700.0          35             2
# 2               0  central  Arganzuela   790.0          40             1
# 3               4  central  Arganzuela   800.0          40             0
# 4               0  central  Arganzuela   800.0          35             1
# ...           ...      ...         ...     ...         ...           ...
# 8177            0  central  Villaverde  1465.0          45             1
# 8178            3  central  Villaverde  1475.0          64             2
# 8179            0  central  Villaverde  1500.0          90             4
# 8180            0  central  Villaverde  1895.0          80             2
# 8181            0  central  Villaverde  2300.0          65             2
#
#       plantas  caract  ascensor  garaje       €/m2  distrito_€/m2  \
# 0           3       3         3       0  24.000000      21.037674
# 1           0       1         0       0  20.000000      21.037674
# 2           1       0         1       0  19.750000      21.037674
# 3           3       3         3       0  20.000000      21.037674
# 4           4       0         1       0  22.857143      21.037674
# ...       ...     ...       ...     ...        ...            ...
# 8177        6       1         1       0  32.555556      15.340223
# 8178        5       1         1       0  23.046875      15.340223
# 8179        6       1         1       0  16.666667      15.340223
# 8180        0       1         1       0  23.687500      15.340223
# 8181        1       3         0       0  35.384615      15.340223
#
#         media_alq    pais  ciudad
# 0     1530.949664  españa  madrid
# 1     1530.949664  españa  madrid
# 2     1530.949664  españa  madrid
# 3     1530.949664  españa  madrid
# 4     1530.949664  españa  madrid
# ...           ...     ...     ...
# 8177  1022.743902  españa  madrid
# 8178  1022.743902  españa  madrid
# 8179  1022.743902  españa  madrid
# 8180  1022.743902  españa  madrid
# 8181  1022.743902  españa  madrid
#
# [8182 rows x 15 columns]

# %%
alquiler.Distrito.value_counts()
# Out:
# Distrito
# Centro                   1263
# Salamanca                 957
# noroeste                  693
# norte                     658
# Chamberi                  582
# Chamartin                 516
# Tetuan                    507
# Retiro                    299
# Arganzuela                298
# Moncloa - Aravaca         264
# sur                       258
# Hortaleza                 245
# Fuencarral - El Pardo     242
# Ciudad Lineal             207
# corredor de henares       182
# San Blas - Canillejas     143
# Latina                    137
# Carabanchel               122
# Puente de Vallecas        105
# sureste                    91
# Villaverde                 82
# Usera                      70
# Vicalvaro                  70
# Villa de Vallecas          67
# suroeste                   66
# Barajas                    30
# Moratalaz                  28
# Name: count, dtype: int64

# %%
#df1 = alquiler
df1 = alquiler[alquiler['Distrito']=='Latina']

# %%
sns.boxplot(x=df1['precio'])
plt.show()

# %%
df1 = df1.drop(columns=['distrito_€/m2','€/m2','zona','Distrito','media_alq','garaje','pais','ciudad'])
#df1 = df1.drop(columns=['distrito_€/m2','€/m2','media_alq'])
#df1 = df1.drop(columns=['distrito_€/m2','€/m2','media_alq','garaje','ascensor','caract'])

# %%
X = df1.drop('precio', axis=1)

y = df1.precio

# %%
X_train, X_test, y_train, y_test = tts(X, y,
                                      train_size=0.8,
                                      test_size=0.2,
                                      random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((109, 6), (28, 6), (109,), (28,))

# %%
"""X = pd.get_dummies(X, columns=['distrito'], dtype=int, drop_first=True)

X_train = pd.get_dummies(X_train, columns=['distrito'], dtype=int, drop_first=True)

X_test = pd.get_dummies(X_test, columns=['distrito'], dtype=int, drop_first=True)"""
# Out:
# "X = pd.get_dummies(X, columns=['distrito'], dtype=int, drop_first=True)\n\nX_train = pd.get_dummies(X_train, columns=['distrito'], dtype=int, drop_first=True)\n\nX_test = pd.get_dummies(X_test, columns=['distrito'], dtype=int, drop_first=True)"

# %%
"""X = pd.get_dummies(X, columns=['zona'], dtype=int, drop_first=True)

X_train = pd.get_dummies(X_train, columns=['zona'], dtype=int, drop_first=True)

X_test = pd.get_dummies(X_test, columns=['zona'], dtype=int, drop_first=True)"""
# Out:
# "X = pd.get_dummies(X, columns=['zona'], dtype=int, drop_first=True)\n\nX_train = pd.get_dummies(X_train, columns=['zona'], dtype=int, drop_first=True)\n\nX_test = pd.get_dummies(X_test, columns=['zona'], dtype=int, drop_first=True)"

# %%
rfr = RFR(n_estimators=500, random_state=20)

rfr.fit(X_train, y_train)

y_pred = rfr.predict(X_test)

mse(y_test, y_pred, squared=False)
# Out:
# 155.6055673137949

# %%
print(f"Test accuracy: {rfr.score(X_test, y_test):0.4f}")
# Out:
# Test accuracy: 0.5783

# %%
df1.precio.mean()
# Out:
# 1181.094890510949

# %%
mse(y_test, y_pred, squared=False)*100/df1.precio.mean()
# Out:
# 13.174688042759964

# %%
dict(zip(X.columns, rfr.feature_importances_*100))
# Out:
# {'descripcion': 1.597182219921079,
#  'superficie': 54.626175846620164,
#  'habitaciones': 14.323077206127296,
#  'plantas': 20.859368917014855,
#  'caract': 2.187931303985146,
#  'ascensor': 6.406264506331465}

# %%
xgbr=XGBR(random_state=42)

xgbr.fit(X_train, y_train)

y_pred = xgbr.predict(X_test)

mse(y_test, y_pred, squared=False)
# Out:
# 177.6735986169549

# %%
print(f"Test accuracy: {xgbr.score(X_test, y_test):0.4f}")
# Out:
# Test accuracy: 0.4502

# %%
df1.precio.mean()
# Out:
# 1181.094890510949

# %%
mse(y_test, y_pred, squared=False)*100/df1.precio.mean()
# Out:
# 15.043126512899587

# %%
dict(zip(X.columns, xgbr.feature_importances_*100))
# Out:
# {'descripcion': 10.4896345,
#  'superficie': 24.293768,
#  'habitaciones': 14.759249,
#  'plantas': 16.12489,
#  'caract': 21.141054,
#  'ascensor': 13.191398}

# %%
X1 = df1.drop(columns='precio')
y1 = df1.precio

# %%
xgbr=XGBR(random_state=42)
xgbr.fit(X1, y1)
y1_pred = xgbr.predict(X1)
mse(y1_pred, y1, squared=False)
# Out:
# 29.344412106728324

# %%
dict(zip(X.columns, xgbr.feature_importances_*100))
# Out:
# {'descripcion': 5.563608,
#  'superficie': 29.656008,
#  'habitaciones': 22.446705,
#  'plantas': 14.315594,
#  'caract': 17.051176,
#  'ascensor': 10.966911}

# %%
df1.precio.mean()
# Out:
# 1181.094890510949

# %%
print(f"Test accuracy: {xgbr.score(X1, y1):0.4f}")
# Out:
# Test accuracy: 0.9869

# %%
mse(y1_pred, y1, squared=False)*100/df1.precio.mean()
# Out:
# 2.484509275459972

# %%
y1_pred = pd.DataFrame(y1_pred, columns=['prediccion'])
y1 = pd.DataFrame(y1)

# %%
y1 = y1.reset_index(drop=True)
y1_pred = y1_pred.reset_index(drop=True)

# %%
con = pd.concat([y1,y1_pred], axis=1)

# %%
con['dif'] = abs(con['precio'] - con['prediccion'])

con['porcen'] = con['dif']*100/ con['precio']

# %%
con
# Out:
#      precio   prediccion         dif     porcen
# 0     675.0   675.002319    0.002319   0.000344
# 1     700.0   698.320007    1.679993   0.239999
# 2     750.0   965.663574  215.663574  28.755143
# 3     750.0   762.085388   12.085388   1.611385
# 4     780.0   777.300293    2.699707   0.346116
# 5     780.0   777.538391    2.461609   0.315591
# 6     800.0   805.149597    5.149597   0.643700
# 7     850.0   856.273376    6.273376   0.738044
# 8     850.0   851.846130    1.846130   0.217192
# 9     875.0   883.051514    8.051514   0.920173
# 10    890.0   890.244751    0.244751   0.027500
# 11    895.0   903.143250    8.143250   0.909860
# 12    895.0   900.638184    5.638184   0.629965
# 13    900.0   889.889954   10.110046   1.123338
# 14    900.0   896.571106    3.428894   0.380988
# 15    900.0   893.691895    6.308105   0.700901
# 16    900.0   941.254944   41.254944   4.583883
# 17    925.0   925.129700    0.129700   0.014022
# 18    930.0   930.173218    0.173218   0.018626
# 19    950.0   988.072937   38.072937   4.007678
# 20    950.0   947.692078    2.307922   0.242939
# 21    950.0   948.877197    1.122803   0.118190
# 22    950.0   954.611328    4.611328   0.485403
# 23    950.0   956.659485    6.659485   0.700998
# 24    950.0   950.057068    0.057068   0.006007
# 25    950.0   949.384827    0.615173   0.064755
# 26    950.0   954.535095    4.535095   0.477378
# 27    950.0   952.625793    2.625793   0.276399
# 28    960.0   960.494019    0.494019   0.051460
# 29    970.0   968.578674    1.421326   0.146528
# 30    975.0   973.457703    1.542297   0.158184
# 31    980.0   979.010376    0.989624   0.100982
# 32    980.0   941.254944   38.745056   3.953577
# 33    990.0   990.308472    0.308472   0.031159
# 34    990.0   998.496155    8.496155   0.858197
# 35    995.0   991.539795    3.460205   0.347759
# 36    999.0   965.663574   33.336426   3.336980
# 37   1000.0  1004.125488    4.125488   0.412549
# 38   1000.0  1007.860657    7.860657   0.786066
# 39   1000.0   999.989319    0.010681   0.001068
# 40   1000.0  1001.015259    1.015259   0.101526
# 41   1000.0   998.102661    1.897339   0.189734
# 42   1000.0  1000.127563    0.127563   0.012756
# 43   1000.0  1002.246582    2.246582   0.224658
# 44   1000.0  1012.804565   12.804565   1.280457
# 45   1005.0  1009.613281    4.613281   0.459033
# 46   1050.0  1067.836060   17.836060   1.698672
# 47   1050.0  1067.836060   17.836060   1.698672
# 48   1050.0  1039.197021   10.802979   1.028855
# 49   1050.0  1050.201660    0.201660   0.019206
# 50   1060.0  1056.600952    3.399048   0.320665
# 51   1100.0  1099.546997    0.453003   0.041182
# 52   1100.0  1091.495850    8.504150   0.773105
# 53   1100.0  1095.367188    4.632812   0.421165
# 54   1100.0  1101.067261    1.067261   0.097024
# 55   1100.0  1099.546997    0.453003   0.041182
# 56   1100.0  1098.934814    1.065186   0.096835
# 57   1100.0  1067.836060   32.163940   2.923995
# 58   1150.0  1150.301636    0.301636   0.026229
# 59   1150.0  1152.144653    2.144653   0.186492
# 60   1150.0  1147.789062    2.210938   0.192255
# 61   1150.0  1150.833130    0.833130   0.072446
# 62   1150.0   965.663574  184.336426  16.029254
# 63   1150.0  1153.986450    3.986450   0.346648
# 64   1175.0  1174.378418    0.621582   0.052901
# 65   1175.0  1176.049683    1.049683   0.089335
# 66   1190.0  1188.652588    1.347412   0.113228
# 67   1200.0  1205.134399    5.134399   0.427867
# 68   1200.0  1199.661133    0.338867   0.028239
# 69   1200.0  1199.772339    0.227661   0.018972
