# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)

# %%
alquiler_arganzuela = pd.read_csv('../../data_alquiler/alquiler_arganzuela_total.csv')
alquiler_barajas = pd.read_csv('../../data_alquiler/alquiler_barajas_total.csv')
alquiler_bsalamanca = pd.read_csv('../../data_alquiler/alquiler_bsalamanca_total.csv')
alquiler_carabanchel = pd.read_csv('../../data_alquiler/alquiler_carabanchel_total.csv')
alquiler_centro = pd.read_csv('../../data_alquiler/alquiler_centro_total.csv')
alquiler_chamartin = pd.read_csv('../../data_alquiler/alquiler_chamartin_total.csv')
alquiler_chamberi = pd.read_csv('../../data_alquiler/alquiler_chamberi_total.csv')
alquiler_ciudadlineal = pd.read_csv('../../data_alquiler/alquiler_ciudadlineal_total.csv')
alquiler_corredorhenares = pd.read_csv('../../data_alquiler/alquiler_corredorhenares_total.csv')
alquiler_fuencarral = pd.read_csv('../../data_alquiler/alquiler_fuencarral_total.csv')
alquiler_hortaleza = pd.read_csv('../../data_alquiler/alquiler_hortaleza_total.csv')
alquiler_latina = pd.read_csv('../../data_alquiler/alquiler_latina_total.csv')
alquiler_moncloa = pd.read_csv('../../data_alquiler/alquiler_moncloa_total.csv')
alquiler_moratalaz = pd.read_csv('../../data_alquiler/alquiler_moratalaz_total.csv')
alquiler_noroeste = pd.read_csv('../../data_alquiler/alquiler_noroeste_total.csv')
alquiler_norte = pd.read_csv('../../data_alquiler/alquiler_norte_total.csv')
alquiler_puentevallecas = pd.read_csv('../../data_alquiler/alquiler_puentevallecas_total.csv')
alquiler_retiro = pd.read_csv('../../data_alquiler/alquiler_retiro_total.csv')
alquiler_sanblas = pd.read_csv('../../data_alquiler/alquiler_sanblas_total.csv')
alquiler_sur = pd.read_csv('../../data_alquiler/alquiler_sur_total.csv')
alquiler_sureste = pd.read_csv('../../data_alquiler/alquiler_sureste_total.csv')
alquiler_suroeste = pd.read_csv('../../data_alquiler/alquiler_suroeste_total.csv')
alquiler_tetuan = pd.read_csv('../../data_alquiler/alquiler_tetuan_total.csv')
alquiler_usera = pd.read_csv('../../data_alquiler/alquiler_usera_total.csv')
alquiler_vicalvaro = pd.read_csv('../../data_alquiler/alquiler_vicalvaro_total.csv')
alquiler_villavallecas = pd.read_csv('../../data_alquiler/alquiler_villavallecas_total.csv')
alquiler_villaverde = pd.read_csv('../../data_alquiler/alquiler_villaverde_total.csv')

# %%
columnas_interesantes2 = ['item-link', 'item-link href', 'item-price', 'item-detail', 'item-detail 2', 'item-detail 3']
columnas_interesantes = ['item-link', 'item-link href', 'item-price', 'item-detail', 'item-detail 2', 'item-detail 3','item-detail 4']
columnas_interesantes3 = ['item-link', 'item-link href', 'item-price', 'item-detail', 'item-detail 2', 'item-detail 3','item-parking','item-detail 4']
columnas_interesantes4 = ['item-link', 'item-link href', 'item-price', 'item-detail', 'item-detail 2', 'item-detail 3','item-parking']

# %%
alquiler_arganzuela = alquiler_arganzuela.loc[:, columnas_interesantes]
alquiler_barajas = alquiler_barajas.loc[:, columnas_interesantes3]
alquiler_bsalamanca = alquiler_bsalamanca.loc[:, columnas_interesantes]
alquiler_carabanchel =alquiler_carabanchel.loc[:, columnas_interesantes3]
alquiler_centro = alquiler_centro.loc[:, columnas_interesantes]
alquiler_chamartin = alquiler_chamartin.loc[:, columnas_interesantes3]
alquiler_chamberi = alquiler_chamberi.loc[:, columnas_interesantes]
alquiler_ciudadlineal = alquiler_ciudadlineal.loc[:, columnas_interesantes]
alquiler_corredorhenares = alquiler_corredorhenares.loc[:, columnas_interesantes3]
alquiler_fuencarral = alquiler_fuencarral.loc[:, columnas_interesantes]
alquiler_hortaleza = alquiler_hortaleza.loc[:, columnas_interesantes3]
alquiler_latina = alquiler_latina.loc[:, columnas_interesantes]
alquiler_moncloa = alquiler_moncloa.loc[:, columnas_interesantes3]
alquiler_moratalaz = alquiler_moratalaz.loc[:, columnas_interesantes]
alquiler_noroeste = alquiler_noroeste.loc[:, columnas_interesantes]
alquiler_norte = alquiler_norte.loc[:, columnas_interesantes2]
alquiler_puentevallecas = alquiler_puentevallecas.loc[:, columnas_interesantes]
alquiler_retiro = alquiler_retiro.loc[:, columnas_interesantes]
alquiler_sanblas = alquiler_sanblas.loc[:, columnas_interesantes3]
alquiler_sur = alquiler_sur.loc[:, columnas_interesantes3]
alquiler_sureste = alquiler_sureste.loc[:, columnas_interesantes3]
alquiler_suroeste = alquiler_suroeste.loc[:, columnas_interesantes3]
alquiler_tetuan = alquiler_tetuan.loc[:, columnas_interesantes]
alquiler_usera = alquiler_usera.loc[:, columnas_interesantes2]
alquiler_vicalvaro = alquiler_vicalvaro.loc[:, columnas_interesantes4]
alquiler_villavallecas = alquiler_villavallecas.loc[:, columnas_interesantes3]
alquiler_villaverde = alquiler_villaverde.loc[:, columnas_interesantes]

# %%
alquiler_arganzuela['zona'] = 'alquiler_arganzuela'
alquiler_barajas['zona'] = 'alquiler_arganzuela'
alquiler_bsalamanca['zona'] = 'alquiler_arganzuela'
alquiler_carabanchel['zona'] = 'alquiler_arganzuela'
alquiler_centro['zona'] = 'alquiler_arganzuela'
alquiler_chamartin['zona'] = 'alquiler_arganzuela'
alquiler_chamberi['zona'] = 'alquiler_arganzuela'
alquiler_ciudadlineal['zona'] = 'alquiler_arganzuela'
alquiler_corredorhenares = alquiler_corredorhenares.loc[:, columnas_interesantes3]
alquiler_fuencarral = alquiler_fuencarral.loc[:, columnas_interesantes]
alquiler_hortaleza = alquiler_hortaleza.loc[:, columnas_interesantes3]
alquiler_latina = alquiler_latina.loc[:, columnas_interesantes]
alquiler_moncloa = alquiler_moncloa.loc[:, columnas_interesantes3]
alquiler_moratalaz = alquiler_moratalaz.loc[:, columnas_interesantes]
alquiler_noroeste = alquiler_noroeste.loc[:, columnas_interesantes]
alquiler_norte = alquiler_norte.loc[:, columnas_interesantes2]
alquiler_puentevallecas = alquiler_puentevallecas.loc[:, columnas_interesantes]
alquiler_retiro = alquiler_retiro.loc[:, columnas_interesantes]
alquiler_sanblas = alquiler_sanblas.loc[:, columnas_interesantes3]
alquiler_sur = alquiler_sur.loc[:, columnas_interesantes3]
alquiler_sureste = alquiler_sureste.loc[:, columnas_interesantes3]
alquiler_suroeste = alquiler_suroeste.loc[:, columnas_interesantes3]
alquiler_tetuan = alquiler_tetuan.loc[:, columnas_interesantes]
alquiler_usera = alquiler_usera.loc[:, columnas_interesantes2]
alquiler_vicalvaro = alquiler_vicalvaro.loc[:, columnas_interesantes4]
alquiler_villavallecas = alquiler_villavallecas.loc[:, columnas_interesantes3]
alquiler_villaverde = alquiler_villaverde.loc[:, columnas_interesantes]

# %%
lst_alquiler = [
    alquiler_arganzuela, alquiler_barajas, alquiler_bsalamanca,
    alquiler_carabanchel, alquiler_centro, alquiler_chamartin,
    alquiler_chamberi, alquiler_ciudadlineal, alquiler_corredorhenares,
    alquiler_fuencarral, alquiler_hortaleza, alquiler_latina,
    alquiler_moncloa, alquiler_moratalaz, alquiler_noroeste,
    alquiler_norte, alquiler_puentevallecas, alquiler_retiro,
    alquiler_sanblas, alquiler_sur, alquiler_sureste,
    alquiler_suroeste, alquiler_tetuan, alquiler_usera,
    alquiler_vicalvaro, alquiler_villavallecas, alquiler_villaverde
]

# %%
alquiler = pd.concat(lst_alquiler)

alquiler
# Out:
#                                             item-link  \
# 0       Estudio en calle de Cáceres, Delicias, Madrid
# 1   Piso en pasaje de ancora, 3, Palos de Moguer, ...
# 2   Piso en calle del General Lacy, Palos de Mogue...
# 3   Estudio en calle de Manzanares, 17, Imperial, ...
# 4   Piso en paseo de las Delicias, Palos de Moguer...
# ..                                                ...
# 79  Piso en calle Pan y Toros, 42, Los Ángeles, Ma...
# 80  Piso en calle de las Viñas del Rio, 12, Butarq...
# 81       Piso en calle Moncada, San Cristóbal, Madrid
# 82         Piso en calle Calcio, 11, Butarque, Madrid
# 83                  Dúplex en Villaverde Alto, Madrid
#
#                                    item-link href  item-price item-detail  \
# 0   https://www.idealista.com/inmueble/104203638/     600.000       25 m²
# 1   https://www.idealista.com/inmueble/104188925/     700.000      2 hab.
# 2    https://www.idealista.com/inmueble/99156781/     790.000      1 hab.
# ...

# %%
"""for df in lst_alquiler:
    print(df.columns)"""
# Out:
# Index(['item-link', 'item-link href', 'item-price', 'item-detail',
#        'item-detail 2', 'item-detail 3', 'item-detail 4'],
#       dtype='object')
# Index(['item-link', 'item-link href', 'item-price', 'item-detail',
#        'item-detail 2', 'item-detail 3', 'item-parking', 'item-detail 4'],
#       dtype='object')
# Index(['item-link', 'item-link href', 'item-price', 'item-detail',
#        'item-detail 2', 'item-detail 3', 'item-detail 4'],
#       dtype='object')
# Index(['item-link', 'item-link href', 'item-price', 'item-detail',
#        'item-detail 2', 'item-detail 3', 'item-parking', 'item-detail 4'],
#       dtype='object')
# Index(['item-link', 'item-link href', 'item-price', 'item-detail',
#        'item-detail 2', 'item-detail 3', 'item-detail 4'],
#       dtype='object')
# Index(['item-link', 'item-link href', 'item-price', 'item-detail',
#        'item-detail 2', 'item-detail 3', 'item-parking', 'item-detail 4'],
#       dtype='object')
# ...

# %%
"""for df in lst_alquiler:
    print(df.shape)"""
# Out:
# (298, 7)
# (45, 8)
# (959, 7)
# (125, 8)
# (1270, 7)
# (516, 8)
# (584, 7)
# (207, 7)
# (185, 8)
# (245, 7)
# (245, 8)
# (137, 7)
# (264, 8)
# (28, 7)
# (696, 7)
# (658, 6)
# (105, 7)
# (299, 7)
# (143, 8)
# (259, 8)
# (97, 8)
# (66, 8)
# (514, 7)
# (70, 6)
# (73, 7)
# (67, 8)
# (84, 7)

# %%
alquiler.rename(columns={
    'item-link': 'descripcion',
    'item-link href': 'link',
    'item-price': 'precio',
    'item-parking': 'park',
    'item-detail 4': 'dia'
}, inplace=True)

# %%
alquiler.precio.describe()
# Out:
# count    8227.000000
# mean      134.498752
# std       311.701557
# min         1.000000
# 25%         1.400000
# 50%         2.100000
# 75%         4.400000
# max       999.000000
# Name: precio, dtype: float64

# %%
alquiler.isna().sum()
# Out:
# descripcion        12
# link               12
# precio              0
# item-detail        12
# item-detail 2      26
# item-detail 3    2310
# dia              5587
# park             7219
# dtype: int64

# %%
alquiler['precio'] = alquiler['precio'].astype(str).str.replace('.', '')

# %%
alquiler.head(100)
# Out:
#                                           descripcion  \
# 0       Estudio en calle de Cáceres, Delicias, Madrid
# 1   Piso en pasaje de ancora, 3, Palos de Moguer, ...
# 2   Piso en calle del General Lacy, Palos de Mogue...
# 3   Estudio en calle de Manzanares, 17, Imperial, ...
# 4   Piso en paseo de las Delicias, Palos de Moguer...
# 5   Piso en calle del Áncora, Palos de Moguer, Madrid
# 6       Piso en paseo de las Acacias, Acacias, Madrid
# 7    Estudio en calle de Arganda, 39, Acacias, Madrid
# 8   Piso en calle del Áncora, 21, Palos de Moguer,...
# 9   Piso en calle de las Penuelas, 34, Acacias, Ma...
# 10  Estudio en glorieta Embajadores, 3, Acacias, M...
# 11                 Estudio en Palos de Moguer, Madrid
# 12     Piso en paseo De La Esperanza, Acacias, Madrid
# 13      Piso en calle de Cáceres, 35, Chopera, Madrid
# 14  Estudio en calle de Gil Imón, 8, Imperial, Madrid
# 15  Piso en calle de Martín de Vargas, 32, Acacias...
# ...

# %%
alquiler['precio'] = alquiler['precio'].astype(int)
