# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/barriosalamanca_min-650k.csv')

# %%
df.head(60)
# Out:
#    item-multimedia-pictures  item-multimedia-pictures 2  \
# 1                        1/                        18.0
# 3                        1/                        28.0
# 4                        1/                        38.0
# 6                        1/                        49.0
# 7                        1/                        27.0
# 8                        1/                        39.0
# 9                        1/                        20.0
# 10                       1/                        25.0
# 11                       1/                        20.0
# 12                      NaN                         NaN
# 13                       1/                        17.0
# 14                       1/                        14.0
# 15                       1/                        24.0
# 16                       1/                        24.0
# 17                       1/                        53.0
# 18                       1/                        30.0
# ...

# %%
df.isna().sum()
# Out:
# item-multimedia-pictures         13
# item-multimedia-pictures 2       13
# item-link                         7
# item-link href                    7
# item-price                        8
# txt-big                           8
# item-detail                       8
# item-detail 2                     8
# item-detail 3                    30
# ellipsis                         12
# hidden-contact-phones_text       30
# hidden-contact-phones_text 2     30
# icon-chat                        14
# favorite-btn                      8
# trash-btn                         8
# gallery-fallback src             37
# logo-branding href              256
# logo-branding src               256
# item-parking                    462
# pricedown_price                 462
# pricedown_icon                  462
# dtype: int64

# %%
df.duplicated().any().sum()
# Out:
# 1

# %%
df = df.drop_duplicates()

# %%
df.isna().all(axis=1)
# Out:
# 0       True
# 1      False
# 3      False
# 4      False
# 6      False
#        ...
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# Length: 500, dtype: bool

# %%
df = df.dropna(how='all')
# Out:
#     item-multimedia-pictures  item-multimedia-pictures 2  \
# 1                         1/                        18.0
# 3                         1/                        28.0
# 4                         1/                        38.0
# 6                         1/                        49.0
# 7                         1/                        27.0
# ..                       ...                         ...
# 501                       1/                        29.0
# 502                       1/                        17.0
# 503                       1/                        19.0
# 504                       1/                         4.0
# 505                       1/                         4.0
#
#                                              item-link  \
# 1    Piso en calle de María Teresa, Guindalera, Madrid
# 3             Piso en calle Lagasca, Recoletos, Madrid
# 4          Piso en calle de Lagasca, Recoletos, Madrid
# ...

# %%
df.isna().sum()
# Out:
# item-multimedia-pictures          6
# item-multimedia-pictures 2        6
# item-link                         0
# item-link href                    0
# item-price                        1
# txt-big                           1
# item-detail                       1
# item-detail 2                     1
# item-detail 3                    23
# ellipsis                          5
# hidden-contact-phones_text       23
# hidden-contact-phones_text 2     23
# icon-chat                         7
# favorite-btn                      1
# trash-btn                         1
# gallery-fallback src             30
# logo-branding href              249
# logo-branding src               249
# item-parking                    455
# pricedown_price                 455
# pricedown_icon                  455
# dtype: int64

# %%
df2 = pd.read_csv('../data/__fuencarral_total.csv')

df2.shape
# Out:
# (29, 457)

# %%
df2
# Out:
#    highlighted-text                                            pro src  \
# 0              Top+  https://st3v.idealista.com/98/56/73/1165047088...
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3               Top                                                NaN
# 4               Top                                                NaN
# 5         Destacado                                                NaN
# 6         Destacado                                                NaN
# 7         Destacado                                                NaN
# 8         Destacado                                                NaN
# 9         Destacado                                                NaN
# 10        Destacado                                                NaN
# 11              NaN                                                NaN
# ...

# %%
for idx, column in enumerate(df2.columns):
    print(f"Columna '{column}' tiene índice {idx}")
# Out:
# Columna 'highlighted-text' tiene índice 0
# Columna 'pro src' tiene índice 1
# Columna 'item-multimedia-pictures' tiene índice 2
# Columna 'item-multimedia-pictures 2' tiene índice 3
# Columna 'item-gallery src' tiene índice 4
# Columna 'item-gallery src 2' tiene índice 5
# Columna 'no-show-address-feedback-text' tiene índice 6
# Columna 'map-content src' tiene índice 7
# Columna 'item-multimedia-minipictures--second-image src' tiene índice 8
# Columna 'item-multimedia-minipictures--third-image src' tiene índice 9
# Columna 'item-multimedia-minipictures--plan src' tiene índice 10
# Columna 'logo-branding href' tiene índice 11
# Columna 'logo-branding src' tiene índice 12
# Columna 'hightop-agent href' tiene índice 13
# Columna 'hightop-kind-agent' tiene índice 14
# Columna 'hightop-agent-name' tiene índice 15
# Columna 'item-link' tiene índice 16
# Columna 'item-link href' tiene índice 17
# Columna 'item-price' tiene índice 18
# Columna 'txt-big' tiene índice 19
# ...

# %%
df
# Out:
#     item-multimedia-pictures  item-multimedia-pictures 2  \
# 1                         1/                        18.0
# 3                         1/                        28.0
# 4                         1/                        38.0
# 6                         1/                        49.0
# 7                         1/                        27.0
# ..                       ...                         ...
# 501                       1/                        29.0
# 502                       1/                        17.0
# 503                       1/                        19.0
# 504                       1/                         4.0
# 505                       1/                         4.0
#
#                                              item-link  \
# 1    Piso en calle de María Teresa, Guindalera, Madrid
# 3             Piso en calle Lagasca, Recoletos, Madrid
# 4          Piso en calle de Lagasca, Recoletos, Madrid
# ...

# %%
df3 = pd.read_csv('../data/moncloa_total.csv')

df3
# Out:
#     item-multimedia-pictures  item-multimedia-pictures 2  \
# 0                         1/                         8.0
# 1                         1/                        17.0
# 2                         1/                        24.0
# 3                         1/                        26.0
# 4                         1/                        22.0
# ..                       ...                         ...
# 887                       1/                        35.0
# 888                       1/                        40.0
# 889                       1/                        24.0
# 890                       1/                        24.0
# 891                       1/                        24.0
#
#                                     logo-branding href  \
# 0    https://www.idealista.com/pro/estudio-home-mad...
# 1                https://www.idealista.com/pro/housfy/
# 2                                                  NaN
# ...

# %%
df4 = pd.read_csv('../data/hortaleza_total.csv')

df4
# Out:
#     item-multimedia-pictures  item-multimedia-pictures 2  \
# 0                         1/                         2.0
# 1                         1/                        21.0
# 2                         1/                         9.0
# 3                         1/                        11.0
# 4                         1/                        11.0
# ..                       ...                         ...
# 822                       1/                        18.0
# 823                       1/                        37.0
# 824                       1/                        26.0
# 825                       1/                        57.0
# 826                       1/                        36.0
#
#                                              item-link  \
# 0    Piso en calle del Pintor Lucio Muñoz, Sanchina...
# 1                     Piso en Apóstol Santiago, Madrid
# 2        Piso en calle Belianes, Pinar del Rey, Madrid
# ...
